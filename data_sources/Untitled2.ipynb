# %%
import sqlite3
import pathlib
import os
import pandas as pd
import json
# Out:
# /var/folders/3p/76rt9gg12vg2yxlm073tswvc0000gn/T/ipykernel_66977/4207943148.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open("pop_numbers.json", "r") as f:
    data = json.load(f)
data
# Out:
# [{'year': 2010,
#   'population': 4785437,
#   'stateid': 'AL',
#   'year_state': '2010_AL'},
#  {'year': 2010,
#   'population': 713910,
#   'stateid': 'AK',
#   'year_state': '2010_AK'},
#  {'year': 2010,
#   'population': 6407172,
#   'stateid': 'AZ',
#   'year_state': '2010_AZ'},
#  {'year': 2010,
#   'population': 2921964,
#   'stateid': 'AR',
#   'year_state': '2010_AR'},
#  {'year': 2010,
#   'population': 37319502,
#   'stateid': 'CA',
#   'year_state': '2010_CA'},
#  {'year': 2010,
#   'population': 5047349,
#   'stateid': 'CO',
#   'year_state': '2010_CO'},
#  {'year': 2010,
#   'population': 3579114,
#   'stateid': 'CT',
#   'year_state': '2010_CT'},
#  {'year': 2010,
#   'population': 899593,
#   'stateid': 'DE',
#   'year_state': '2010_DE'},
#  {'year': 2010,
#   'population': 605226,
#   'stateid': 'DC',
#   'year_state': '2010_DC'},
#  {'year': 2010,
#   'population': 18845537,
#   'stateid': 'FL',
#   'year_state': '2010_FL'},
#  {'year': 2010,
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      year  population stateid year_state
# 0    2010     4785437      AL    2010_AL
# 1    2010      713910      AK    2010_AK
# 2    2010     6407172      AZ    2010_AZ
# 3    2010     2921964      AR    2010_AR
# 4    2010    37319502      CA    2010_CA
# ..    ...         ...     ...        ...
# 709  2023     8715698      VA    2023_VA
# 710  2023     7812880      WA    2023_WA
# 711  2023     1770071      WV    2023_WV
# 712  2023     5910955      WI    2023_WI
# 713  2023      584057      WY    2023_WY
#
# [714 rows x 4 columns]
